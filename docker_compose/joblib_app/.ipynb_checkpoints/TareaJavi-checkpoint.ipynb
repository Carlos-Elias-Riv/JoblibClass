# %% [markdown]
# # **Tarea de Joblib**

# %% [markdown]
# Javier Nieto Merodio
# ITAM 2023 FDD

# %% [markdown]
# ## **0. Import de librerías**

# %%
import matplotlib.pyplot as plt
import os
import requests
import numpy as np
import urllib.request
from joblib import Parallel, delayed
import time

# %% [markdown]
# ## **1. Import de las imágenes a un arreglo**

# %%
array_img = np.loadtxt("20_images.txt", dtype="str")
array_img
# Out:
# array(['https://i.ytimg.com/vi/bDPkImgNs8Y/maxresdefault.jpg',
#        'https://e00-marca.uecdn.es/albumes/2014/11/18/comics_nba/1416295630_extras_albumes_0_980.jpg',
#        'https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/fairy-tail-natsu-padres-1559572361.png',
#        'https://static.wikia.nocookie.net/fairytail/images/b/bf/830px-You_like_him.jpg/revision/latest?cb=20120127154134&path-prefix=es',
#        'https://static.wikia.nocookie.net/doblaje/images/7/7c/Dragon-Ball-Z.png/revision/latest?cb=20200911193425&path-prefix=es',
#        'https://depor.com/resizer/EkdERO36Wj8BqMsc67Kd20z2f0U=/1200x1200/smart/filters:format(jpeg):quality(75)/cloudfront-us-east-1.images.arcpublishing.com/elcomercio/NRFDECK2RBDCTKHGOOT5XJQEDI.jpg',
#        'https://www.rd.com/wp-content/uploads/2019/01/shutterstock_673465372.jpg?fit=700,467',
#        'https://images.unsplash.com/photo-1611267254323-4db7b39c732c?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxzZWFyY2h8M3x8Y3V0ZSUyMGNhdHxlbnwwfHwwfHw%3D&w=1000&q=80',
#        'https://wallpaper.dog/large/20523050.png',
#        'https://m.media-amazon.com/images/I/41b9u-1yUVS._AC_.jpg',
#        'https://alejandrolabonneblog.files.wordpress.com/2016/03/cthulhu-2.jpg?w=640',
#        'https://i.etsystatic.com/30793990/r/il/2a09ee/3926159075/il_1080xN.3926159075_hj39.jpg',
#        'https://3.bp.blogspot.com/-WTbenEvaKvw/Va6u1GT-OTI/AAAAAAAAF20/-EMjnitZIUc/s1600/fan-art-chihiro-7.jpg',
#        'https://i.pinimg.com/736x/55/7b/36/557b36ec0911375e91f88c45b9e30a92--batman-animado-chibi.jpg',
#        'https://i.etsystatic.com/39184033/r/il/f49e69/4384629284/il_fullxfull.4384629284_5nk6.jpg',
#        'https://pbs.twimg.com/profile_images/1033772662940684288/CEIJaGZP_400x400.jpg',
#        'https://static.wikia.nocookie.net/lossimpson/images/0/04/El_Barto.png/revision/latest?cb=20160511154723&path-prefix=es',
#        'https://i.redd.it/tvkk3sxgp8181.png',
#        'https://www.bibliatodo.com/chistes-cristianos/wp-content/uploads/2021/07/Ew7fd58XIAIvPRs.png',
#        'https://i.pinimg.com/474x/ee/d6/05/eed60545d30bafa2dd7ce23e9c076801--los-simpsons-cartoon-characters.jpg',
#        'https://www.ciaramolina.com/wp-content/uploads/2016/09/elephant-297205_960_720-768x558.png',
#        'https://http2.mlstatic.com/D_NQ_NP_2X_947005-MLM49480089581_032022-F.jpg',
#        'https://i0.wp.com/soygodin.com/wp-content/uploads/2018/04/787.jpg?w=1000&ssl=1',
#        'https://cdn.pixabay.com/photo/2015/12/01/20/28/road-1072823_1280.jpg',
#        'https://cdn.shopify.com/s/files/1/1468/2844/products/0144502500_gtr_cntbdyright_001_nr_1024x1024.png?v=1637189679',
#        'https://st3.depositphotos.com/11246114/18110/i/450/depositphotos_181108640-stock-photo-beautiful-blue-sky-with-clouds.jpg',
#        'https://e00-marca.uecdn.es/blogs/una-vida-al-filo/imagenes_posts/2018/07/07/194521_696x465.jpg',
#        'https://t1.uc.ltmcdn.com/es/posts/0/6/9/como_hacer_un_sandwich_mixto_33960_orig.jpg',
#        'https://www.elsoldecuernavaca.com.mx/doble-via/328zlv-mariposa-monarca.jpg/ALTERNATES/LANDSCAPE_768/mariposa-monarca.jpg',
#        'https://www.elpalaciodehierro.com/on/demandware.static/-/Sites-palacio-master-catalog/default/dw6ea1efa1/images/19306364/large/19306364_x1.jpg',
#        'https://i.blogs.es/08dfe4/alessandro-cerino-idwpkeo-zwk-unsplash/1366_2000.jpeg',
#        'https://m.media-amazon.com/images/I/71A6YO+yKWL._AC_UF894,1000_QL80_.jpg',
#        'https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Strawberry_ice_cream_cone_%285076899310%29.jpg/640px-Strawberry_ice_cream_cone_%285076899310%29.jpg',
#        'https://www.superprof.mx/blog/wp-content/uploads/2020/01/partituras-de-piano-principiantes.jpg',
#        'https://img.freepik.com/vector-gratis/ilustracion-concepto-computadora-escritorio_114360-12153.jpg?w=2000',
#        'https://www.tiendacanon.com.mx/wcsstore/CMEXCatalogAssetStore/EOS_90D_XL_310522-min.jpg',
#        'https://cdn1.coppel.com/images/catalog/pr/8490562-1.jpg',
#        'https://ichef.bbci.co.uk/news/640/cpsprodpb/183B1/production/_113494299_gettyimages-489937746.jpg',
#        'https://www.ciad.mx/wp-content/uploads/2022/05/MANGO-UN-MANJAR-PARA-LA-SALUD.jpg',
#        'https://img.remediosdigitales.com/c9e90a/audi-rs-3-2022_11/450_1000.jpeg'],
#       dtype='<U191')

# %% [markdown]
# Descarga de las imágenes y salvado en un arreglo

# %%
folder_imgs = './img'
filenames = []

for url in array_img:
    response = requests.get(url)
    filename = url.split('/')[-1]
    with open(os.path.join(folder_imgs, filename), 'wb') as f:
        f.write(response.content)
    filenames.append(filename)

# %% [markdown]
# Prueba de funcionamiento

# %%
imagen_prueba=plt.imread(folder_imgs + "/" +filenames[0])
plt.imshow(imagen_prueba)
plt.show()

# %% [markdown]
# ## **2. Transformas imágenes a vectores**

# %%
# Muestra de qué hay que hacer

imagen_prueba= plt.imread(folder_imgs + "/" +filenames[0])
imagen_prueba = np.array(imagen_prueba)
print(imagen_prueba.shape)
imagen_prueba
# Out:
# (720, 1280, 3)
# array([[[ 60,  38,  27],
#         [ 57,  37,  26],
#         [ 56,  36,  25],
#         ...,
#         [ 51,  74,  80],
#         [ 50,  74,  78],
#         [ 49,  73,  75]],
#
#        [[ 60,  38,  27],
#         [ 57,  37,  26],
#         [ 56,  36,  25],
#         ...,
#         [ 51,  74,  80],
#         [ 49,  73,  77],
#         [ 48,  72,  76]],
#
#        [[ 60,  38,  27],
#         [ 59,  37,  26],
#         [ 56,  36,  25],
#         ...,
#         [ 49,  72,  80],
#         [ 47,  70,  76],
#         [ 47,  71,  75]],
#
#        ...,
#
#        [[ 82,  77,  57],
#         [ 80,  75,  55],
#         [ 78,  73,  54],
#         ...,
#         [185, 198, 217],
#         [185, 198, 217],
#         [185, 198, 217]],
#
#        [[ 93,  88,  68],
#         [ 90,  85,  65],
#         [ 86,  79,  60],
#         ...,
#         [182, 197, 216],
#         [182, 197, 216],
#         [182, 197, 216]],
#
#        [[100,  95,  75],
#         [ 96,  91,  71],
#         [ 91,  84,  65],
#         ...,
#         [182, 197, 216],
#         [181, 196, 215],
#         [181, 196, 215]]], dtype=uint8)

# %%
# Función que vectoriza imágenes

def vectorizar(x): 
    try:
        return plt.imread(x)
    except:
        return "Link roto"

# %%
# Vectorizar todas las imágenes y guardarlas en un vector de forma paralelizada

imagenes_vectorizadas = Parallel(n_jobs= 2)(delayed(vectorizar)(folder_imgs + "/" + i) for i in filenames)
# Out:
# exception calling callback for <Future at 0x11fa9b290 state=finished raised BrokenProcessPool>
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/javi/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/javi/miniconda3/envs/joblib/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: code() argument 13 must be str, not int
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/javi/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/Users/javi/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/parallel.py", line 360, in __call__
#     self.parallel.dispatch_next()
#   File "/Users/javi/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/parallel.py", line 797, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/javi/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/parallel.py", line 864, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/javi/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/javi/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/javi/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/externals/loky/reusable_executor.py", line 177, in submit
#     return super(_ReusablePoolExecutor, self).submit(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/javi/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 1115, in submit
#     raise self._flags.broken
# joblib.externals.loky.process_executor.BrokenProcessPool: A task has failed to un-serialize. Please ensure that the arguments of the function are all picklable.
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/javi/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 407, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/javi/miniconda3/envs/joblib/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: code() argument 13 must be str, not int
# """
#
# The above exception was the direct cause of the following exception:
#
# BrokenProcessPool                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Vectorizar todas las imágenes y guardarlas en un vector de forma paralelizada
# ----> 3 imagenes_vectorizadas = Parallel(n_jobs= 2)(delayed(vectorizar)(folder_imgs + "/" + i) for i in filenames)
#
# File ~/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/parallel.py:1061, in Parallel.__call__(self, iterable)
#    1058     self._iterating = False
#    1060 with self._backend.retrieval_context():
# -> 1061     self.retrieve()
#    1062 # Make sure that we get a last message telling us we are done
#    1063 elapsed_time = time.time() - self._start_time
#
# File ~/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/parallel.py:938, in Parallel.retrieve(self)
#     936 try:
#     937     if getattr(self._backend, 'supports_timeout', False):
# --> 938         self._output.extend(job.get(timeout=self.timeout))
#     939     else:
#     940         self._output.extend(job.get())
#
# File ~/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File ~/miniconda3/envs/joblib/lib/python3.11/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/miniconda3/envs/joblib/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/externals/loky/_base.py:625, in Future._invoke_callbacks(self)
#     623 for callback in self._done_callbacks:
#     624     try:
# --> 625         callback(self)
#     626     except BaseException:
#     627         LOGGER.exception('exception calling callback for %r', self)
#
# File ~/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/parallel.py:360, in BatchCompletionCallBack.__call__(self, out)
#     358 with self.parallel._lock:
#     359     if self.parallel._original_iterator is not None:
# --> 360         self.parallel.dispatch_next()
#
# File ~/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/parallel.py:797, in Parallel.dispatch_next(self)
#     789 def dispatch_next(self):
#     790     """Dispatch more data for parallel processing
#     791
#     792     This method is meant to be called concurrently by the multiprocessing
#    (...)
#     795
#     796     """
# --> 797     if not self.dispatch_one_batch(self._original_iterator):
#     798         self._iterating = False
#     799         self._original_iterator = None
#
# File ~/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/parallel.py:864, in Parallel.dispatch_one_batch(self, iterator)
#     862     return False
#     863 else:
# --> 864     self._dispatch(tasks)
#     865     return True
#
# File ~/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/parallel.py:782, in Parallel._dispatch(self, batch)
#     780 with self._lock:
#     781     job_idx = len(self._jobs)
# --> 782     job = self._backend.apply_async(batch, callback=cb)
#     783     # A job can complete so quickly than its callback is
#     784     # called before we get here, causing self._jobs to
#     785     # grow. To ensure correct results ordering, .insert is
#     786     # used (rather than .append) in the following line
#     787     self._jobs.insert(job_idx, job)
#
# File ~/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/_parallel_backends.py:531, in LokyBackend.apply_async(self, func, callback)
#     529 def apply_async(self, func, callback=None):
#     530     """Schedule a func to be run"""
# --> 531     future = self._workers.submit(SafeFunction(func))
#     532     future.get = functools.partial(self.wrap_future_result, future)
#     533     if callback is not None:
#
# File ~/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/externals/loky/reusable_executor.py:177, in _ReusablePoolExecutor.submit(self, fn, *args, **kwargs)
#     175 def submit(self, fn, *args, **kwargs):
#     176     with self._submit_resize_lock:
# --> 177         return super(_ReusablePoolExecutor, self).submit(
#     178             fn, *args, **kwargs)
#
# File ~/miniconda3/envs/joblib/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:1115, in ProcessPoolExecutor.submit(self, fn, *args, **kwargs)
#    1113 with self._flags.shutdown_lock:
#    1114     if self._flags.broken is not None:
# -> 1115         raise self._flags.broken
#    1116     if self._flags.shutdown:
#    1117         raise ShutdownExecutorError(
#    1118             'cannot schedule new futures after shutdown')
#
# BrokenProcessPool: A task has failed to un-serialize. Please ensure that the arguments of the function are all picklable.

# %%
imagenes_vectorizadas

# %% [markdown]
# ## **3. Obtener el primer color de la imagen**

# %%
### Los pasos que tengan * se deben hacer de manera paralelizada

## Primer paso: cargar los links desde un archivo txt a un arreglo
## *Segundo paso: transformar las imagenes a vectores 
## *Tercer paso: obtener el primer color de la imagen que se obtiene de: colors = np.unique(imagen.reshape(-1, imagen.shape[2]), axis=0)
## *Cuarto paso: cambiar el color de la imagen a un color random
## Quinto paso: hacer un dataframe que tenga el link de la imagen con una columna llamada url, su antiguo color con columna llamada 
## oldcolor y su nuevo color con columna llamada newcolor
## *Sexto paso: hacer una columna nueva que tenga diffcolor como la diferencia numerica entre newcolor y oldcolor
